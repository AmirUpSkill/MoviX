# %%
import pandas as pd
import numpy as np
import joblib
import os
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# --- Configuration ---
DATA_PATH      = '../data/TMDB_all_movies.csv'
MODELS_DIR     = '../models'
POSTER_BASE_URL = "https://image.tmdb.org/t/p/w500"

os.makedirs(MODELS_DIR, exist_ok=True)
print("Setup complete. Artifacts will be saved to:", MODELS_DIR)
# Out:
# Setup complete. Artifacts will be saved to: ../models

# %%
try:
    df_raw = pd.read_csv(DATA_PATH)
    print("Loaded:", df_raw.shape)
except FileNotFoundError as e:
    raise e
df_raw.head(2)
# Out:
# Loaded: (1082514, 28)
#    id                title  vote_average  vote_count    status release_date  \
# 0   2                Ariel         7.111       346.0  Released   1988-10-21
# 1   3  Shadows in Paradise         7.293       409.0  Released   1986-10-17
#
#    revenue  runtime  budget    imdb_id  ...         spoken_languages  \
# 0      0.0     73.0     0.0  tt0094675  ...                    suomi
# 1      0.0     74.0     0.0  tt0092149  ...  suomi, English, svenska
#
#                                                 cast        director  \
# 0  Turo Pajala, Matti Jaaranen, Marja Packalén, J...  Aki Kaurismäki
# 1  Esko Nikkari, Mari Rantasila, Marina Martinoff...  Aki Kaurismäki
#
#    director_of_photography         writers        producers music_composer  \
# 0            Timo Salminen  Aki Kaurismäki   Aki Kaurismäki            NaN
# 1            Timo Salminen  Aki Kaurismäki  Mika Kaurismäki            NaN
#
#   imdb_rating imdb_votes                       poster_path
# 0         7.4     9122.0  /ojDg0PGvs6R9xYFodRct2kdI6wC.jpg
# 1         7.4     7937.0  /nj01hspawPof0mJmlgfjuLyJuRN.jpg
#
# [2 rows x 28 columns]

# %%
"""
    -> Data Cleaning and Preprocessing

"""
cols = ['id','title','overview','genres','cast','director','poster_path','release_date']
df = df_raw[cols].copy()

# --- Safe fillna handling ---
df[['overview','genres','cast','director']] = \
    df[['overview','genres','cast','director']].fillna('')

df = df.dropna(subset=['title'])

# --- Poster URLs ---
df['poster_url'] = df['poster_path'].apply(
    lambda p: f"{POSTER_BASE_URL}{p}" if pd.notna(p) and p else None
)

# --- Normalizer ---
def normalize_list_field(text: str) -> list[str]:
    if not isinstance(text, str) or not text.strip():
        return []
    return [t.strip().lower().replace(' ', '-') for t in text.split(',') if t.strip()]

for col in ['genres', 'cast', 'director']:
    df[col] = df[col].apply(normalize_list_field)

print("Preprocessing done. Shape:", df.shape)
df.head(2)
# Out:
# Preprocessing done. Shape: (1082501, 9)
#    id                title                                           overview  \
# 0   2                Ariel  A Finnish man goes to the city to find a job a...
# 1   3  Shadows in Paradise  Nikander, a rubbish collector and would-be ent...
#
#                             genres  \
# 0  [comedy, drama, romance, crime]
# 1         [comedy, drama, romance]
#
#                                                 cast          director  \
# 0  [turo-pajala, matti-jaaranen, marja-packalén, ...  [aki-kaurismäki]
# 1  [esko-nikkari, mari-rantasila, marina-martinof...  [aki-kaurismäki]
#
#                         poster_path release_date  \
# 0  /ojDg0PGvs6R9xYFodRct2kdI6wC.jpg   1988-10-21
# 1  /nj01hspawPof0mJmlgfjuLyJuRN.jpg   1986-10-17
#
#                                           poster_url
# 0  https://image.tmdb.org/t/p/w500/ojDg0PGvs6R9xY...
# 1  https://image.tmdb.org/t/p/w500/nj01hspawPof0m...

# %%
"""
    -> the requimendation token
"""
def build_tokens(row: pd.Series) -> str:
    genres = [f"genre={g}" for g in row['genres']]
    cast = [f"actor={a}" for a in row['cast'][:5]]
    director = [f"director={d}" for d in row['director'][:1]]
    overview = str(row['overview'] or '')
    # --- make higher weight --- 
    structured = genres + cast + director 
    return " ".join(structured * 2) + " " + overview
df['text'] = df.apply(build_tokens, axis=1)

# --- TF-IDF vectorizer --- 
tfidf = TfidfVectorizer(stop_words='english' , sublinear_tf=True , min_df=3)
tfidf_matrix = tfidf.fit_transform(df['text'])
print("TF-IDF matrix shape:", tfidf_matrix.shape)
# Out:
# TF-IDF matrix shape: (1082501, 281697)

# %%
def recommend_by_filters(
    genres: list[str] | None = None,
    actors: list[str] | None = None,
    keywords: list[str] | None = None,
    k: int = 5
) -> pd.DataFrame:
    """
    Return k movies as a DataFrame that best match the provided filters.
    Each list element should already be lower-cased & hyphenated (like our tokens).
    """
    tokens = (
        [f"genre={g}" for g in (genres or [])] +
        [f"actor={a}" for a in (actors or [])] +
        (keywords or [])
    )
    if not tokens:
        raise ValueError("Provide at least one of genres, actors, or keywords")

    query = " ".join(tokens + tokens) 
    q_vec = tfidf.transform([query])
    scores = (tfidf_matrix @ q_vec.T).toarray().ravel()

    top_idx = np.argpartition(scores, -k)[-k:]
    top_idx = top_idx[np.argsort(scores[top_idx])[::-1]]

    cols_needed = ['id','title','release_date','poster_url','genres','cast']
    return df.iloc[top_idx][cols_needed].reset_index(drop=True)

# %%
recommend_by_filters(genres=['action','drama'],actors=['tom-hanks'],keywords=['war'])
# Out:
#         id                title release_date  \
# 0  1447933         The Americas          NaN
# 1  1116589  Die Tom Hanks Story   2021-07-14
# 2  1322493               crumbs          NaN
# 3   638302     Major Matt Mason          NaN
# 4  1198548      A Timeless Call   2008-08-27
#
#                                           poster_url  \
# 0  https://image.tmdb.org/t/p/w500/3xoXA77BOjN50q...
# 1                                               None
# 2                                               None
# 3                                               None
# 4  https://image.tmdb.org/t/p/w500/eSIJDlKvMt1Oll...
#
#                         genres         cast
# 0                           []  [tom-hanks]
# 1                [documentary]  [tom-hanks]
# 2                           []  [tom-hanks]
# 3  [adventure, action, family]  [tom-hanks]
# 4           [documentary, war]  [tom-hanks]

# %%
# --- Test al-pacino and robert-de-niro --- 
recommendation_df = recommend_by_filters(
    genres = ['crime','drama'],
    actors = ['al-pacino','robert-de-niro'],
    keywords = ['mafia']
)

recommendation_df.head(5)
# Out:
#         id                                 title release_date  \
# 0  1458013                Scarface 3mk w3m 3yalk          NaN
# 1  1006912  Pacino and De Niro: The Conversation   2005-02-22
# 2   651724         The Irishman: In Conversation   2019-11-27
# 3   328733                            Babbleonia   2005-07-12
# 4   926616                    Becoming Al Pacino   2022-02-06
#
#                                           poster_url  \
# 0  https://image.tmdb.org/t/p/w500/m73Z89kkGQqKPS...
# 1  https://image.tmdb.org/t/p/w500/geTzP43feBnimS...
# 2  https://image.tmdb.org/t/p/w500/fF704pR8xsNjI7...
# 3  https://image.tmdb.org/t/p/w500/1VsfOjGGDy6bfi...
# 4  https://image.tmdb.org/t/p/w500/sOWjfvdokidKwB...
#
#                              genres  \
# 0                                []
# 1                     [documentary]
# 2                     [documentary]
# 3                     [documentary]
# 4  [documentary, history, tv-movie]
#
#                                                 cast
# 0                                 [3zeef, al-pacino]
# 1  [jon-voight, robert-de-niro, michael-mann, al-...
# 2  [martin-scorsese, robert-de-niro, joe-pesci, a...
# 3                                        [al-pacino]
# 4  [al-pacino, sarah-jane-sauvegrain, robert-de-n...
