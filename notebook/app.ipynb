# %%
import pandas as pd 
import numpy as np 
import joblib 
import os 
from sklearn.feature_extraction.text import TfidfVectorizer

# --- Configuration --- 
DATA_PATH = '../data/TMDB_all_movies.csv'
MODELS_DIR = '../models'
POSTER_BASE_URL = "https://image.tmdb.org/t/p/w500"
# --- Create the models directory if it doesn't exist --- 
os.makedirs(MODELS_DIR, exist_ok=True)
# --- print the result --- 
print("Setup Complete. Models will be saved to:", MODELS_DIR)
# Out:
# Setup Complete. Models will be saved to: ../models

# %%
# --- Load the dataSet ---
try:
    df = pd.read_csv(DATA_PATH)
    print("DataSet loaded successfully")
    print("Shape of the dataset:" , df.shape)
except FileNotFoundError:
    print(f"Error : DataSet i not found at {DATA_PATH}. Please ensure the file is in the correct dir")
    df = pd.DataFrame()
df.head(3)
# Out:
# DataSet loaded successfully
# Shape of the dataset: (1082514, 28)
#    id                title  vote_average  vote_count    status release_date  \
# 0   2                Ariel         7.111       346.0  Released   1988-10-21
# 1   3  Shadows in Paradise         7.293       409.0  Released   1986-10-17
# 2   5           Four Rooms         5.900      2685.0  Released   1995-12-09
#
#      revenue  runtime     budget    imdb_id  ...         spoken_languages  \
# 0        0.0     73.0        0.0  tt0094675  ...                    suomi
# 1        0.0     74.0        0.0  tt0092149  ...  suomi, English, svenska
# 2  4257354.0     98.0  4000000.0  tt0113101  ...                  English
#
#                                                 cast  \
# 0  Turo Pajala, Matti Jaaranen, Marja Packalén, J...
# 1  Esko Nikkari, Mari Rantasila, Marina Martinoff...
# 2  Tamlyn Tomita, Tim Roth, Madonna, Paul Caldero...
#
#                                             director  \
# 0                                     Aki Kaurismäki
# 1                                     Aki Kaurismäki
# 2  Robert Rodriguez, Quentin Tarantino, Alexandre...
#
#                              director_of_photography  \
# 0                                      Timo Salminen
# 1                                      Timo Salminen
# 2  Andrzej Sekula, Rodrigo García, Phil Parmet, G...
#
#                                              writers  \
# 0                                     Aki Kaurismäki
# 1                                     Aki Kaurismäki
# 2  Robert Rodriguez, Quentin Tarantino, Alexandre...
#
#                                            producers      music_composer  \
# 0                                     Aki Kaurismäki                 NaN
# 1                                    Mika Kaurismäki                 NaN
# 2  Lawrence Bender, Quentin Tarantino, Alexandre ...  Combustible Edison
#
#   imdb_rating imdb_votes                       poster_path
# 0         7.4     9122.0  /ojDg0PGvs6R9xYFodRct2kdI6wC.jpg
# 1         7.4     7937.0  /nj01hspawPof0mJmlgfjuLyJuRN.jpg
# 2         6.7   113944.0  /75aHn1NOYXh4M7L5shoeQ6NGykP.jpg
#
# [3 rows x 28 columns]
